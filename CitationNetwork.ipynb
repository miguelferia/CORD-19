# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
# pd.options.display.max_colwidth = 500
from tqdm import tqdm

from multiprocessing import cpu_count, Pool #for multiprocessing data
cores = cpu_count()
import re

#imports for network analysis
import networkx as nx #for creating networl
import community #pip install python-louvain; for determining communities

# %%
data = pd.read_csv('all_sources_metadata_2020-03-13.csv')

# %%
data = data.dropna(subset=['abstract'])
data.head(2) #check out what it looks like
# Out:
#                                         sha source_x  \
# 2  210a892deb1c61577f6fba58505fd65356ce6636      CZI
# 3  e3b40cc8e0e137c416b4a2273a4dca94ae8178cc      CZI
#
#                                                title                 doi  \
# 2  Incubation Period and Other Epidemiological Ch...  10.3390/jcm9020538
# 3  Characteristics of and Public Health Responses...  10.3390/jcm9020575
#
#   pmcid   pubmed_id license  \
# 2   NaN         NaN   cc-by
# 3   NaN  32093211.0   cc-by
#
#                                             abstract publish_time  \
# 2  The geographic spread of 2019 novel coronaviru...         2020
# 3  In December 2019, cases of unidentified pneumo...         2020
#
#                                              authors  \
# 2  Linton, M. Natalie; Kobayashi, Tetsuro; Yang, ...
# 3                   Deng, Sheng-Qun; Peng, Hong-Juan
#
#                         journal  Microsoft Academic Paper ID WHO #Covidence  \
# ...

# %%
auths = data['authors'].to_list()
authors = [l.split(';') for l in auths]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-19bca785ebfe> in <module>
#       1 auths = data['authors'].to_list()
# ----> 2 authors = [l.split(';') for l in auths]
#
# <ipython-input-9-19bca785ebfe> in <listcomp>(.0)
#       1 auths = data['authors'].to_list()
# ----> 2 authors = [l.split(';') for l in auths]
#
# AttributeError: 'float' object has no attribute 'split'

# %%
[a for a in auths]
# Out:
# ['Linton, M. Natalie; Kobayashi, Tetsuro; Yang, Yichi; Hayashi, Katsuma; Akhmetzhanov, R. Andrei; Jung, Sung-mok; Yuan, Baoyin; Kinoshita, Ryo; Nishiura, Hiroshi',
#  'Deng, Sheng-Qun; Peng, Hong-Juan',
#  'Tang, Biao; Bragazzi, Nicola Luigi; Li, Qian; Tang, Sanyi; Xiao, Yanni; Wu, Jianhong',
#  'Roosa, K.; Lee, Y.; Luo, R.; Kirpich, A.; Rothenberg, R.; Hyman, J. M.; Yan, P.; Chowell, G.',
#  'Rocklöv, J.; Sjödin, H.; Wilder-Smith, A.',
#  'Qing, Enya; Hantak, Michael; Perlman, Stanley; Gallagher, Tom',
#  'Chen, Xinguang; Yu, Bin',
#  'Quilty, Billy J; Clifford, Sam; group2, CMMID nCoV working; Flasche, Stefan; Eggo, Rosalind M',
#  'Cleemput, S.; Dumon, W.; Fonseca, V.; Karim, W. A.; Giovanetti, M.; Alcantara, L. C.; Deforche, K.; de Oliveira, T.',
#  'Lim, Jaegyun; Jeon, Seunghyun; Shin, Hyun-Young; Kim, Moon Jung; Seong, Yu Min; Lee, Wang Jun; Choe, Kang-Won; Kang, Yu Min; Lee, Baeckseung; Park, Sang-Joon',
#  'Shanmugaraj, Balamurugan; Malla, Ashwini; Phoolcharoen, Waranyoo',
# ...
